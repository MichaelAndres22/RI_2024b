# %% [markdown]
# # Web Scrapping
#
# ## Nombre: Michael Pillaga

# %% [markdown]
# ## Instalación de dependencias

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)

# %% [markdown]
# ## Paso 1: Web Scraping
#
# Este código realiza **web scraping** en el sitio web de AllRecipes para extraer información detallada de recetas. Primero, recopila enlaces de todas las categorías de recetas disponibles. Luego, para cada categoría, extrae las URL de las recetas y recopila detalles como el título, descripción, ingredientes y pasos de cada receta. Los resultados, organizados por categoría, se almacenan en un archivo JSON llamado `all_recipes.json`. Se utiliza la biblioteca `BeautifulSoup` para analizar el contenido HTML, y se limita la extracción a un máximo de 500 recetas para evitar sobrecargar el servidor.

# %%
import requests
from bs4 import BeautifulSoup
import time
import json
from tqdm import tqdm

# Encabezados para simular un navegador
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "Connection": "keep-alive"
}

BASE_URL = "https://www.allrecipes.com"
CATEGORIES_URL = f"{BASE_URL}/recipes-a-z-6735880"
MAX_RECIPES = 500

# Función para obtener todas las URLs de las categorías
def get_category_urls():
    response = requests.get(CATEGORIES_URL, headers=HEADERS)
    if response.status_code != 200:
        print(f"Error fetching categories page: {response.status_code}")
        return []

    soup = BeautifulSoup(response.content, "html.parser")

    category_links = []
    for group in soup.select(".mntl-alphabetical-list__group"):
        for a_tag in group.select("a[href]"):
            category_links.append(a_tag["href"])

    print(f"Found {len(category_links)} categories.")
    return category_links

# Función para obtener todas las recetas de una categoría
def get_recipes_from_category(category_url):
    recipes = []

    while category_url and len(recipes) < MAX_RECIPES:
        print(f"Fetching recipes from: {category_url}")
        response = requests.get(category_url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Error fetching category page: {response.status_code}")
            break

        soup = BeautifulSoup(response.content, "html.parser")

        # Obtener las URLs de las recetas en los contenedores con IDs dinámicos
        for group_container in soup.select('[id^="mntl-taxonomysc-article-list-group_"]'):
            for recirc_container in group_container.select('[id^="tax-sc__recirc-list-container_"]'):
                for recipe_tag in recirc_container.select("a[href]"):
                    recipes.append(recipe_tag["href"])
                    if len(recipes) >= MAX_RECIPES:
                        break
                if len(recipes) >= MAX_RECIPES:
                    break
            if len(recipes) >= MAX_RECIPES:
                break

        print(f"Found {len(recipes)} recipes so far.")

        # Buscar el enlace a la siguiente página
        next_page_tag = soup.select_one(".category-page-list-related-nav-next-button a")
        category_url = next_page_tag["href"] if next_page_tag else None

        # Espera para evitar bloqueos
        time.sleep(1)

    return recipes

# Función para extraer información de una receta
def get_recipe_details(recipe_url):
    print(f"Fetching details for recipe: {recipe_url}")
    response = requests.get(recipe_url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Error fetching recipe page: {response.status_code}")
        return None

    soup = BeautifulSoup(response.content, "html.parser")

    # Extraer título
    title_tag = soup.find(class_="article-heading text-headline-400")
    title = title_tag.text.strip() if title_tag else "No title found"

    # Extraer descripción
    description_tag = soup.find(class_="article-subheading text-body-100")
    description = description_tag.text.strip() if description_tag else "No description found"

    # Extraer ingredientes
    ingredients_tag = soup.find(class_="mm-recipes-structured-ingredients__list")
    ingredients = [li.text.strip() for li in ingredients_tag.find_all("li")] if ingredients_tag else []

    # Extraer pasos
    steps_tag = soup.find(id="mm-recipes-steps__content_1-0")
    steps = [p.text.strip() for p in steps_tag.find_all("p")] if steps_tag else []

    return {
        "title": title,
        "description": description,
        "ingredients": ingredients,
        "steps": steps,
        "url": recipe_url
    }

# Función principal para obtener todas las recetas por categoría
def scrape_all_recipes():
    categories = get_category_urls()
    if not categories:
        print("No categories found. Exiting.")
        return {}

    all_recipes = {}

    total_recipes = 0
    for category_url in tqdm(categories, desc="Scraping categories"):
        if total_recipes >= MAX_RECIPES:
            print("Reached the maximum number of recipes.")
            break

        category_name = category_url.split("/")[-2]
        print(f"Scraping category: {category_name}")

        recipes = get_recipes_from_category(category_url)
        recipe_details = []

        for recipe_url in recipes:
            if len(recipe_details) >= MAX_RECIPES:
                break
            details = get_recipe_details(recipe_url)
            if details:
                recipe_details.append(details)

        all_recipes[category_name] = {
            "count": len(recipe_details),
            "recipes": recipe_details
        }

        total_recipes += len(recipe_details)
        print(f"Category '{category_name}' has {len(recipe_details)} recipes.")

        # Espera para evitar bloqueos
        time.sleep(2)

    return all_recipes

if __name__ == "__main__":
    all_recipes_data = scrape_all_recipes()

    # Mostrar resultados en el output (solo las primeras 3 recetas de cada categoría)
    for category, data in all_recipes_data.items():
        print(f"Category: {category}")
        print(f"Total Recipes: {data['count']}")
        print("Sample Recipes:")
        for recipe in data["recipes"][:3]:
            print(f"- {recipe['title']}: {recipe['url']}")
        print()

    # Guardar los datos en un archivo JSON (con todas las recetas hasta el límite de 500)
    with open("all_recipes.json", "w", encoding="utf-8") as f:
        json.dump(all_recipes_data, f, ensure_ascii=False, indent=4)

    print("Scraping completado. Datos guardados en 'all_recipes.json'.")
# Out:
# Found 378 categories.
# Scraping categories:   0%|          | 0/378 [00:00<?, ?it/s]
# Scraping category: air-fryer
# Fetching recipes from: https://www.allrecipes.com/recipes/23070/everyday-cooking/cookware-and-equipment/air-fryer/
# Found 64 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-lemon-garlic-parmesan-chicken-recipe-8726749
# Fetching details for recipe: https://www.allrecipes.com/best-air-fryer-thanksgiving-recipes-8729089
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-s-mores-recipe-8736955
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-baked-yams-recipe-8737640
# Fetching details for recipe: https://www.allrecipes.com/lemon-garlic-butter-chicken-spiedini-recipe-8727930
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-grilled-pimento-cheese-recipe-8720986
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-chicken-parmesan-recipe-8698442
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-eggplant-recipe-8700773
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-sriracha-fries-recipe-8694021
# Fetching details for recipe: https://www.allrecipes.com/crispy-air-fryer-potato-bites-recipe-8682451
# Fetching details for recipe: https://www.allrecipes.com/copycat-wingstop-cajun-corn-recipe-8681405
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-po-boy-recipe-8647044
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-buffalo-wings-recipe-8645970
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-smashed-potatoes-recipe-8644582
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-quesadillas-recipe-8651442
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-truffle-polenta-fries-recipe-8643717
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-firecracker-salmon-bites-recipe-8623119
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-chicken-bites-recipe-8599352
# Fetching details for recipe: https://www.allrecipes.com/4-ingredient-air-fryer-pepper-poppers-recipe-8584965
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-bell-pepper-poppers-recipe-8584648
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-cinnamon-roll-bites-recipe-8553617
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-ham-and-cheese-wraps-recipe-8365118
# Fetching details for recipe: https://www.allrecipes.com/recipe/8537905/air-fryer-buffalo-cauliflower/
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-honey-mustard-chicken-thighs-recipe-7970816
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-hearts-of-palm-sticks-recipe-7814346
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-cheesy-bacon-ranch-french-fries-recipe-7560981
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-mini-dark-chocolate-cake-with-brown-butter-frosting-recipe-7509612
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-spanakopita-recipe-7510155
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-pecan-crusted-trout-recipe-7510184
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-blooming-onion-recipe-7546676
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-tempura-vegetables-recipe-7510181
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-turtle-cheesecake-recipe-7511366
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-samosas-recipe-7510128
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-roasted-vegetables-with-gremolata-and-red-pepper-aioli-recipe-7510058
# Fetching details for recipe: https://www.allrecipes.com/crab-rangoon-in-the-air-fryer-recipe-7511370
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-everything-bagel-salmon-dinner-recipe-7509518
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-crispy-pickle-chips-with-creole-dipping-sauce-recipe-7509784
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-raspberry-brownie-bites-recipe-7509875
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-sweet-potato-chips-recipe-7510177
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-green-bean-fries-recipe-7509535
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-loaded-egg-salad-sandwiches-recipe-7509591
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-chicken-tenders-recipe-7509380
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-garlic-green-beans-recipe-7511002
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-green-beans-recipe-7510925
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-chicken-tenders-recipe-7501758
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-honey-garlic-chicken-wings-recipe-7501470
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-pizookie-recipe-7501307
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-cheese-curds-recipe-7500004
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-grilled-ham-and-cheese-recipe-7485060
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-bacon-wrapped-brussels-sprouts-recipe-7484095
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-scrambled-eggs-recipe-7482374
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-waffle-egg-in-a-hole-7377995
# Fetching details for recipe: https://www.allrecipes.com/air-fryer-caramelized-bananas-recipe-7373417
# Fetching details for recipe: https://www.allrecipes.com/article/i-tried-a-tiktok-trick-for-cleaning-my-air-fryer/
# Fetching details for recipe: https://www.allrecipes.com/article/air-fry-meat-fish-frozen/
# Fetching details for recipe: https://www.allrecipes.com/article/how-healthy-is-air-fryer-cooking/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8525657/air-fryer-lemon-pepper-roasted-cashews/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8537838/air-fryer-pretzel-crescent-rolls/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8532490/air-fryer-crispy-cajun-black-eyed-peas/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8532969/quick-air-fryer-tilapia/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8529798/air-fryer-chickpeas/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8527072/air-fryer-loaded-mashed-potato-cakes/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8457744/air-fryer-chicken-bites-with-parmesan-cheese/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8457748/air-fryer-mini-croissants-with-nutella-and-jam/
# Category 'air-fryer' has 64 recipes.
# Scraping categories:   0%|          | 1/378 [00:33<3:29:35, 33.36s/it]
# Scraping category: allrecipes-allstars
# Fetching recipes from: https://www.allrecipes.com/recipes/16492/everyday-cooking/special-collections/allrecipes-allstars/
# Found 64 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/halibut-en-papillote-recipe-8775088
# Fetching details for recipe: https://www.allrecipes.com/thai-peanut-butter-ramen-recipe-8775397
# Fetching details for recipe: https://www.allrecipes.com/italian-ricotta-cookie-bars-recipe-8775003
# Fetching details for recipe: https://www.allrecipes.com/passion-fruit-mojito-recipe-8774704
# Fetching details for recipe: https://www.allrecipes.com/apple-cider-pork-tenderloin-with-sweet-potatoes-recipe-8774666
# Fetching details for recipe: https://www.allrecipes.com/mediterranean-salmon-baked-in-parchment-recipe-8768509
# Fetching details for recipe: https://www.allrecipes.com/nordstrom-s-tomato-basil-soup-recipe-8769886
# Fetching details for recipe: https://www.allrecipes.com/baked-sweet-and-sour-chicken-thighs-with-pineapple-recipe-8607437
# Fetching details for recipe: https://www.allrecipes.com/sheet-pan-lemon-balsamic-chicken-and-potatoes-recipe-8769182
# Fetching details for recipe: https://www.allrecipes.com/green-goddess-chicken-and-cucumber-wraps-recipe-8768451
# Fetching details for recipe: https://www.allrecipes.com/easy-parmesan-garlic-ramen-recipe-8770557
# Fetching details for recipe: https://www.allrecipes.com/copycat-chick-fil-a-chicken-tortilla-soup-recipe-8768430
# Fetching details for recipe: https://www.allrecipes.com/mediterranean-salmon-baked-in-foil-recipe-8768562
# Fetching details for recipe: https://www.allrecipes.com/hot-honey-roasted-cauliflower-recipe-8768267
# Fetching details for recipe: https://www.allrecipes.com/miso-aioli-recipe-8768230
# Fetching details for recipe: https://www.allrecipes.com/boursin-pork-chops-recipe-8763443
# Fetching details for recipe: https://www.allrecipes.com/allstars-go-to-easy-weeknight-dinners-8759476
# Fetching details for recipe: https://www.allrecipes.com/12-quick-and-easy-weeknight-dinners-8764204
# Fetching details for recipe: https://www.allrecipes.com/justin-rowlands-philly-cheesesteak-egg-rolls-recipe-8762569
# Fetching details for recipe: https://www.allrecipes.com/cod-piccata-recipe-8763624
# Fetching details for recipe: https://www.allrecipes.com/tortellini-lasagna-skillet-recipe-8754041
# Fetching details for recipe: https://www.allrecipes.com/christmas-cheesecake-bars-recipe-8762231
# Fetching details for recipe: https://www.allrecipes.com/pomegranate-glazed-salmon-recipe-8760727
# Fetching details for recipe: https://www.allrecipes.com/cauliflower-cheddar-soup-recipe-8761982
# Fetching details for recipe: https://www.allrecipes.com/creamy-brie-and-bacon-pasta-recipe-8761429
# Fetching details for recipe: https://www.allrecipes.com/slow-cooker-sausage-tortellini-soup-recipe-8762313
# Fetching details for recipe: https://www.allrecipes.com/baked-boursin-tomato-dip-recipe-8761942
# Fetching details for recipe: https://www.allrecipes.com/bang-bang-salmon-recipe-8748368
# Fetching details for recipe: https://www.allrecipes.com/ranch-bloody-mary-recipe-8760838
# Fetching details for recipe: https://www.allrecipes.com/boursin-omelet-recipe-8750293
# Fetching details for recipe: https://www.allrecipes.com/christmas-tree-cheese-ball-recipe-8762179
# Fetching details for recipe: https://www.allrecipes.com/cheesy-garlic-mashed-potatoes-recipe-8752836
# Fetching details for recipe: https://www.allrecipes.com/goat-cheese-stuffed-dates-recipe-8759685
# Fetching details for recipe: https://www.allrecipes.com/turmeric-black-pepper-chicken-with-broccoli-recipe-8750707
# Fetching details for recipe: https://www.allrecipes.com/sheet-pan-lemon-garlic-chicken-with-vegetables-recipe-8750712
# Fetching details for recipe: https://www.allrecipes.com/creamy-gochujang-spaghetti-with-ground-beef-recipe-8750088
# Fetching details for recipe: https://www.allrecipes.com/christmas-ornament-cheese-ball-recipe-8759389
# Fetching details for recipe: https://www.allrecipes.com/honey-mustard-ham-and-cheese-sliders-recipe-8752303
# Fetching details for recipe: https://www.allrecipes.com/roasted-honey-garlic-cauliflower-recipe-8759182
# Fetching details for recipe: https://www.allrecipes.com/cheesy-garlic-zucchini-steaks-recipe-8750131
# Fetching details for recipe: https://www.allrecipes.com/everything-bagel-greek-yogurt-dip-recipe-8756899
# Fetching details for recipe: https://www.allrecipes.com/mediterranean-deviled-eggs-recipe-8756876
# Fetching details for recipe: https://www.allrecipes.com/garlic-butter-steak-bites-with-mushrooms-recipe-8751632
# Fetching details for recipe: https://www.allrecipes.com/halloumi-breakfast-sandwiches-recipe-8752997
# Fetching details for recipe: https://www.allrecipes.com/baked-mac-and-cheese-bites-recipe-8751356
# Fetching details for recipe: https://www.allrecipes.com/carrot-cake-baked-oatmeal-recipe-8735685
# Fetching details for recipe: https://www.allrecipes.com/christmas-cookie-bars-recipe-8753567
# Fetching details for recipe: https://www.allrecipes.com/ultimate-pumpkin-custard-pie-recipe-8746429
# Fetching details for recipe: https://www.allrecipes.com/shrimp-stir-fry-with-snap-peas-and-baby-corn-recipe-8753997
# Fetching details for recipe: https://www.allrecipes.com/gingerbread-latte-cookies-recipe-8753574
# Fetching details for recipe: https://www.allrecipes.com/high-protein-egg-salad-recipe-8753831
# Fetching details for recipe: https://www.allrecipes.com/easy-zucchini-mushroom-skillet-recipe-8753947
# Fetching details for recipe: https://www.allrecipes.com/creamy-mango-cocktail-recipe-8753582
# Fetching details for recipe: https://www.allrecipes.com/leftover-mashed-potato-egg-cups-recipe-8754019
# Fetching details for recipe: https://www.allrecipes.com/butter-basted-rib-eye-steak-recipe-8753374
# Fetching details for recipe: https://www.allrecipes.com/everything-bagel-grilled-cheese-recipe-8753365
# Fetching details for recipe: https://www.allrecipes.com/reverse-dalgona-iced-coffee-recipe-8753865
# Fetching details for recipe: https://www.allrecipes.com/slow-cooker-loaded-potato-chowder-recipe-8752868
# Fetching details for recipe: https://www.allrecipes.com/everything-pigs-in-a-blanket-recipe-8752531
# Fetching details for recipe: https://www.allrecipes.com/boursin-scrambled-eggs-recipe-8750323
# Fetching details for recipe: https://www.allrecipes.com/5-ingredient-tortilla-soup-recipe-8748332
# Fetching details for recipe: https://www.allrecipes.com/blueberry-orange-bread-recipe-8745793
# Fetching details for recipe: https://www.allrecipes.com/jam-jewel-cookies-recipe-8748207
# Fetching details for recipe: https://www.allrecipes.com/double-chocolate-biscotti-with-cherries-recipe-8748242
# Category 'allrecipes-allstars' has 64 recipes.
# Scraping categories:   1%|          | 2/378 [01:06<3:28:13, 33.23s/it]
# Scraping category: angel-food-cake
# Fetching recipes from: https://www.allrecipes.com/recipes/385/desserts/cakes/angel-food-cake/
# Found 15 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/recipe/7868/mock-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/244321/heavenly-raspberry-dessert/
# Fetching details for recipe: https://www.allrecipes.com/recipe/25981/cherry-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/72998/high-altitude-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/283630/2-ingredient-pineapple-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8428/homemade-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/283629/microwave-mini-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/article/2-ingredient-cake-makes-cheap-and-easy-dessert/
# Fetching details for recipe: https://www.allrecipes.com/recipe/285354/gluten-free-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/242013/honey-angel-food-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/23733/chocolate-angel-food-cake-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/7751/angel-food-cake-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/261545/toasted-angel-food-cake-with-strawberries/
# Fetching details for recipe: https://www.allrecipes.com/recipe/7884/two-part-angel-cake/
# Fetching details for recipe: https://www.allrecipes.com/recipe/7324/angel-food-cake-i/
# Category 'angel-food-cake' has 15 recipes.
# Scraping categories:   1%|          | 3/378 [01:16<2:21:59, 22.72s/it]
# Scraping category: antipasto
# Fetching recipes from: https://www.allrecipes.com/recipes/102/appetizers-and-snacks/antipasto/
# Found 34 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/recipe/106695/prosciutto-e-melone-italian-ham-and-melon/
# Fetching details for recipe: https://www.allrecipes.com/recipe/53144/cherry-pepper-poppers/
# Fetching details for recipe: https://www.allrecipes.com/antipasti-garlic-bread-recipe-8716000
# Fetching details for recipe: https://www.allrecipes.com/recipe/104806/tomato-and-mozzarella-bites/
# Fetching details for recipe: https://www.allrecipes.com/recipe/234616/fried-stuffed-squash-blossoms/
# Fetching details for recipe: https://www.allrecipes.com/recipe/23401/antipasto/
# Fetching details for recipe: https://www.allrecipes.com/recipe/57808/antipasto-squares/
# Fetching details for recipe: https://www.allrecipes.com/recipe/213849/caprese-on-a-stick/
# Fetching details for recipe: https://www.allrecipes.com/recipe/254419/watermelon-caprese-appetizer/
# Fetching details for recipe: https://www.allrecipes.com/recipe/223453/italian-tuna-spread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266150/marinated-mushrooms-for-antipasto/
# Fetching details for recipe: https://www.allrecipes.com/recipe/26694/antipasto-platter/
# Fetching details for recipe: https://www.allrecipes.com/recipe/244601/grilled-prosciutto-wrapped-peaches-with-burrata-and-basil/
# Fetching details for recipe: https://www.allrecipes.com/recipe/273496/festive-olive-and-cheese-appetizer/
# Fetching details for recipe: https://www.allrecipes.com/recipe/273527/caprese-skewers/
# Fetching details for recipe: https://www.allrecipes.com/recipe/259466/easy-caponata/
# Fetching details for recipe: https://www.allrecipes.com/recipe/213064/roasted-peppers-in-oil-peperoni-arrostiti-sotto-olio/
# Fetching details for recipe: https://www.allrecipes.com/recipe/247347/tortellini-skewers/
# Fetching details for recipe: https://www.allrecipes.com/recipe/23949/boniet/
# Fetching details for recipe: https://www.allrecipes.com/recipe/254228/gluten-free-stuffed-zucchini-blossoms-fior-di-zucca-ripieni/
# Fetching details for recipe: https://www.allrecipes.com/recipe/223533/roasted-veggie-antipasto/
# Fetching details for recipe: https://www.allrecipes.com/recipe/280731/marinated-stuffed-cherry-peppers/
# Fetching details for recipe: https://www.allrecipes.com/recipe/72907/prosciutto-wrapped-melon-balls/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266153/bruschetta-with-peas-and-mint/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266157/grissini-with-prosciutto/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266156/easy-marinated-feta/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266148/zucchini-feta-rolls/
# Fetching details for recipe: https://www.allrecipes.com/recipe/275374/blackberry-basil-skewers/
# Fetching details for recipe: https://www.allrecipes.com/recipe/273956/cherry-tomato-bites/
# Fetching details for recipe: https://www.allrecipes.com/recipe/245129/eggplant-and-tomato-caponata/
# Fetching details for recipe: https://www.allrecipes.com/recipe/254694/ruths-eggplant-caponata/
# Fetching details for recipe: https://www.allrecipes.com/recipe/273529/marinated-feta/
# Fetching details for recipe: https://www.allrecipes.com/article/fratelli-beretta-possible-source-salmonella-outbreak-italian-meats/
# Fetching details for recipe: https://www.allrecipes.com/recipe/20945/magaricz/
# Category 'antipasto' has 34 recipes.
# Scraping categories:   1%|          | 4/378 [01:36<2:14:50, 21.63s/it]
# Scraping category: appetizers-and-snacks
# Fetching recipes from: https://www.allrecipes.com/recipes/76/appetizers-and-snacks/
# Found 64 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/recipe/51326/chinese-tea-leaf-eggs/
# Fetching details for recipe: https://www.allrecipes.com/cheese-puff-sliders-recipe-8768983
# Fetching details for recipe: https://www.allrecipes.com/miso-aioli-recipe-8768230
# Fetching details for recipe: https://www.allrecipes.com/bang-bang-chicken-nuggets-recipe-8767654
# Fetching details for recipe: https://www.allrecipes.com/mediterranean-marinated-cheese-recipe-8767492
# Fetching details for recipe: https://www.allrecipes.com/the-best-salmon-cakes-recipe-8764931
# Fetching details for recipe: https://www.allrecipes.com/salmon-cream-cheese-recipe-8764414
# Fetching details for recipe: https://www.allrecipes.com/justin-rowlands-philly-cheesesteak-egg-rolls-recipe-8762569
# Fetching details for recipe: https://www.allrecipes.com/baked-boursin-tomato-dip-recipe-8761942
# Fetching details for recipe: https://www.allrecipes.com/christmas-tree-cheese-ball-recipe-8762179
# Fetching details for recipe: https://www.allrecipes.com/goat-cheese-stuffed-dates-recipe-8759685
# Fetching details for recipe: https://www.allrecipes.com/million-dollar-snack-mix-recipe-8747298
# Fetching details for recipe: https://www.allrecipes.com/christmas-ornament-cheese-ball-recipe-8759389
# Fetching details for recipe: https://www.allrecipes.com/everything-bagel-greek-yogurt-dip-recipe-8756899
# Fetching details for recipe: https://www.allrecipes.com/mediterranean-deviled-eggs-recipe-8756876
# Fetching details for recipe: https://www.allrecipes.com/mac-and-cheese-cowboy-cups-recipe-8758352
# Fetching details for recipe: https://www.allrecipes.com/trees-a-crowd-cheese-ball-recipe-8740108
# Fetching details for recipe: https://www.allrecipes.com/garlic-butter-baked-brie-in-a-box-recipe-8756783
# Fetching details for recipe: https://www.allrecipes.com/caramelized-onion-and-bacon-baked-brie-with-fig-jam-recipe-8756680
# Fetching details for recipe: https://www.allrecipes.com/garlic-butter-steak-bites-with-mushrooms-recipe-8751632
# Fetching details for recipe: https://www.allrecipes.com/baked-mac-and-cheese-bites-recipe-8751356
# Fetching details for recipe: https://www.allrecipes.com/za-atar-chicken-wings-recipe-8754648
# Fetching details for recipe: https://www.allrecipes.com/2-ingredient-everything-bagel-chicken-wings-recipe-8748399
# Fetching details for recipe: https://www.allrecipes.com/cranberry-brie-pull-apart-bread-recipe-8732507
# Fetching details for recipe: https://www.allrecipes.com/honey-glazed-halloumi-recipe-8747293
# Fetching details for recipe: https://www.allrecipes.com/ginger-orange-upside-down-tarts-recipe-8745418
# Fetching details for recipe: https://www.allrecipes.com/olive-cheese-balls-recipe-8741888
# Fetching details for recipe: https://www.allrecipes.com/best-smoked-salmon-dip-recipe-8741722
# Fetching details for recipe: https://www.allrecipes.com/20-best-southern-thanksgiving-appetizers-8746904
# Fetching details for recipe: https://www.allrecipes.com/smoked-turkey-collard-green-dip-recipe-8742549
# Fetching details for recipe: https://www.allrecipes.com/creamy-jalapeno-cranberry-dip-recipe-8742601
# Fetching details for recipe: https://www.allrecipes.com/beet-pickled-deviled-eggs-recipe-8743663
# Fetching details for recipe: https://www.allrecipes.com/cranberry-cheese-ball-recipe-8726774
# Fetching details for recipe: https://www.allrecipes.com/coconut-chicken-tenders-recipe-8732536
# Fetching details for recipe: https://www.allrecipes.com/truffle-deviled-eggs-recipe-8739284
# Fetching details for recipe: https://www.allrecipes.com/chicken-adobo-tacos-recipe-8736734
# Fetching details for recipe: https://www.allrecipes.com/roscoe-s-chilaquiles-recipe-8739658
# Fetching details for recipe: https://www.allrecipes.com/pecan-pie-cheese-ball-recipe-8732389
# Fetching details for recipe: https://www.allrecipes.com/fall-jarcuterie-recipe-8739666
# Fetching details for recipe: https://www.allrecipes.com/beef-and-bean-tiny-tacos-recipe-8727881
# Fetching details for recipe: https://www.allrecipes.com/pigs-in-a-blanket-wreath-recipe-8736042
# Fetching details for recipe: https://www.allrecipes.com/crispy-brie-and-cranberry-rice-paper-bites-recipe-8734076
# Fetching details for recipe: https://www.allrecipes.com/million-dollar-holiday-party-sliders-recipe-8734072
# Fetching details for recipe: https://www.allrecipes.com/cranberry-jalapeno-dip-recipe-8732450
# Fetching details for recipe: https://www.allrecipes.com/faddys-meatballs-appetizer-8734081
# Fetching details for recipe: https://www.allrecipes.com/melting-snowman-board-8734068
# Fetching details for recipe: https://www.allrecipes.com/sriracha-deviled-eggs-with-bacon-recipe-8733320
# Fetching details for recipe: https://www.allrecipes.com/tuna-melt-nachos-recipe-8733919
# Fetching details for recipe: https://www.allrecipes.com/sausage-stuffed-mini-peppers-recipe-8733406
# Fetching details for recipe: https://www.allrecipes.com/sriracha-deviled-eggs-recipe-8730021
# Fetching details for recipe: https://www.allrecipes.com/lemon-garlic-butter-chicken-spiedini-recipe-8727930
# Fetching details for recipe: https://www.allrecipes.com/slow-cooker-chicken-apple-butter-meatballs-recipe-8715002
# Fetching details for recipe: https://www.allrecipes.com/stuffed-mini-peppers-recipe-8730240
# Fetching details for recipe: https://www.allrecipes.com/everything-bagel-deviled-eggs-recipe-8729732
# Fetching details for recipe: https://www.allrecipes.com/easy-tiktok-pizza-appetizer-recipe-8660871
# Fetching details for recipe: https://www.allrecipes.com/onion-patties-recipe-8710524
# Fetching details for recipe: https://www.allrecipes.com/smoked-mackerel-beets-apples-and-bread-crisps-recipe-8722324
# Fetching details for recipe: https://www.allrecipes.com/salted-pretzel-church-window-cookies-recipe-8722397
# Fetching details for recipe: https://www.allrecipes.com/peanut-butter-bugle-bites-recipe-8724424
# Fetching details for recipe: https://www.allrecipes.com/pumpkin-cheese-ball-recipe-8725706
# Fetching details for recipe: https://www.allrecipes.com/mango-shrimp-ceviche-recipe-8724391
# Fetching details for recipe: https://www.allrecipes.com/copycat-chuy-s-creamy-jalapeno-ranch-dip-recipe-8710491
# Fetching details for recipe: https://www.allrecipes.com/pomegranate-pistachio-crostini-recipe-8721396
# Fetching details for recipe: https://www.allrecipes.com/sausage-head-charcuterie-board-recipe-8715948
# Category 'appetizers-and-snacks' has 64 recipes.
# Scraping categories:   1%|▏         | 5/378 [02:10<2:41:06, 25.92s/it]
# Scraping category: apple-pie
# Fetching recipes from: https://www.allrecipes.com/recipes/788/desserts/pies/apple-pie/
# Found 64 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/caramel-apple-pie-cookies-recipe-7642173
# Fetching details for recipe: https://www.allrecipes.com/recipe/230243/moms-cranberry-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12682/apple-pie-by-grandma-ople/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12681/apple-pie-filling/
# Fetching details for recipe: https://www.allrecipes.com/recipe/230610/apple-tarte-tatin/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15942/canned-apple-pie-filling/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12324/apple-pie-i/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15587/apple-crumb-pie/
# Fetching details for recipe: https://www.allrecipes.com/croatian-apple-pie-squares-recipe-7508367
# Fetching details for recipe: https://www.allrecipes.com/recipe/12583/old-fashioned-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12680/fried-apple-pies/
# Fetching details for recipe: https://www.allrecipes.com/recipe/213569/grandmas-iron-skillet-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15697/no-sugar-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/220997/chef-johns-caramel-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/255719/perfect-apple-crisp-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/54628/easy-swedish-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219165/chef-johns-easy-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/274026/air-fryer-apple-pies/
# Fetching details for recipe: https://www.allrecipes.com/recipe/274000/easy-air-fryer-apple-pies/
# Fetching details for recipe: https://www.allrecipes.com/recipe/238839/easy-apple-kuchen/
# Fetching details for recipe: https://www.allrecipes.com/recipe/57582/sour-cream-apple-pie-deluxe/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219617/mini-apple-pies/
# Fetching details for recipe: https://www.allrecipes.com/recipe/258330/appeltaart-dutch-apple-tart/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12298/apple-crumble-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/206369/apple-pie-in-a-brown-paper-bag/
# Fetching details for recipe: https://www.allrecipes.com/recipe/19460/apple-slab-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/23766/danish-pastry-apple-bars/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12191/dutch-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17263/apple-streusel-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/237305/apple-slice-squares/
# Fetching details for recipe: https://www.allrecipes.com/recipe/13622/aunt-carols-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/77874/french-apple-tart-tarte-de-pommes-a-la-normande/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15083/best-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16268/apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/18353/all-american-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12092/american-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15911/applesauce-custard-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/19969/swedish-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/41719/apple-berry-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/241839/iron-skillet-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/267993/easy-german-apple-streusel-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/43022/upside-down-apple-pecan-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/13820/glazed-apple-cream-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15069/fast-apple-rhubarb-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/77447/warm-apple-pocket/
# Fetching details for recipe: https://www.allrecipes.com/recipe/232892/caramel-apple-walnut-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/232434/apple-blackberry-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/223280/creamy-apple-blueberry-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219432/healthier-apple-pie-by-grandma-ople/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15902/sundays-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/244426/rustic-fruit-galette/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15785/fresh-apple-tarts/
# Fetching details for recipe: https://www.allrecipes.com/recipe/18464/mums-irish-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15941/apple-pie-iv/
# Fetching details for recipe: https://www.allrecipes.com/recipe/18431/impossible-french-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/255858/vegan-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/285643/individual-honeycrisp-apple-tarts/
# Fetching details for recipe: https://www.allrecipes.com/recipe/12526/apple-pie-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/107321/campfire-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15904/moms-apple-pie-i/
# Fetching details for recipe: https://www.allrecipes.com/recipe/174368/caramel-apple-crumble-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/234035/canadian-apple-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/255720/apple-oat-crisp-pie/
# Fetching details for recipe: https://www.allrecipes.com/recipe/13859/no-added-sugar-apple-pie/
# Category 'apple-pie' has 64 recipes.
# Scraping categories:   2%|▏         | 6/378 [02:47<3:04:23, 29.74s/it]
# Scraping category: applesauce
# Fetching recipes from: https://www.allrecipes.com/recipes/1333/side-dish/applesauce/
# Found 31 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/recipe/234078/applesauce-for-the-freezer/
# Fetching details for recipe: https://www.allrecipes.com/applesauce-muffins-recipe-8702299
# Fetching details for recipe: https://www.allrecipes.com/recipe/13643/cranberry-sauce-extraordinaire/
# Fetching details for recipe: https://www.allrecipes.com/recipe/267958/cranberry-sauce-with-apples/
# Fetching details for recipe: https://www.allrecipes.com/recipe/223485/no-cook-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/233160/willis-farm-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/142643/blushing-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/228653/slow-cooker-cider-applesauce-no-sugar-added/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219275/dougs-easy-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/234993/easy-cranberry-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/267972/instant-pot-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266329/holiday-cranberry-and-apple-compote/
# Fetching details for recipe: https://www.allrecipes.com/article/difference-between-applesauce-and-apple-butter/
# Fetching details for recipe: https://www.allrecipes.com/recipe/154394/superb-cranberry-sauce-with-apples-and-pears/
# Fetching details for recipe: https://www.allrecipes.com/recipe/258363/rosy-strawberry-rhubarb-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/269425/instant-pot-pear-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/230394/chunky-cinnamon-orange-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/239324/apple-pear-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/268199/quince-apple-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/130639/cranberry-pomegranate-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/279878/rhubarb-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/237796/slow-cooker-apple-raspberry-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266328/apple-raisin-compote/
# Fetching details for recipe: https://www.allrecipes.com/recipe/246976/rice-cooker-recipe-raspberry-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/148879/grandmas-cranberry-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/234992/lemon-ginger-cranberry-applesauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/285360/spiced-apple-topping-for-pancakes/
# Fetching details for recipe: https://www.allrecipes.com/recipe/95670/cran-apple-pear-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16051/sams-kicking-cranberry-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219608/awesome-and-easy-cranberry-sauce/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15733/fresh-applesauce/
# Category 'applesauce' has 31 recipes.
# Scraping categories:   2%|▏         | 7/378 [03:05<2:40:28, 25.95s/it]
# Scraping category: artichoke-dip
# Fetching recipes from: https://www.allrecipes.com/recipes/14913/appetizers-and-snacks/dips-and-spreads/artichoke-dip/
# Found 51 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/recipe/33474/artichoke-spinach-dip-restaurant-style/
# Fetching details for recipe: https://www.allrecipes.com/recipe/268013/instant-pot-spinach-and-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/223012/amazing-no-cook-spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/231086/hot-artichoke-and-crab-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/14814/hot-artichoke-spinach-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16651/delicious-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/60357/veronicas-hot-spinach-artichoke-and-chile-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/221191/chef-johns-hot-spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/276776/slow-cooker-spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/26699/artichoke-spinach-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/15141/luscious-spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/282806/baked-spinach-artichoke-dip-without-mayo/
# Fetching details for recipe: https://www.allrecipes.com/recipe/25530/cheesy-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/218995/dipping-sauce-for-artichokes/
# Fetching details for recipe: https://www.allrecipes.com/recipe/240589/easy-creamy-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/24915/hot-spinach-and-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/20672/yummy-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/25537/shrimp-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/14930/florentine-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/22305/artichoke-spread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/20859/artichoke-dip-i/
# Fetching details for recipe: https://www.allrecipes.com/recipe/239156/spinach-artichoke-dip-with-water-chestnuts/
# Fetching details for recipe: https://www.allrecipes.com/recipe/266759/vegan-spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/43413/chicken-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/9541/artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/241634/fabulous-spinach-and-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/9549/artichoke-cheese-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/236189/buffalo-chicken-and-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/58527/justines-artichoke-chicken-spinach-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/283641/hot-spinach-artichoke-and-swiss-cheese-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/220879/artichoke-and-egg-spread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219896/hot-roasted-red-pepper-and-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/282809/artichoke-dip-with-fresh-spinach/
# Fetching details for recipe: https://www.allrecipes.com/recipe/51371/a-and-z-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/262412/absolutely-wonderful-cheesy-creamy-spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219457/healthier-hot-artichoke-and-spinach-dip-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/24739/artichoke-crab-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/20856/uncle-howies-favorite-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/18231/artichoke-and-crab-spread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/245255/skinny-spinach-and-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/60229/amazing-artichoke-and-spinach-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/23945/hot-artichoke-dip-with-green-chiles/
# Fetching details for recipe: https://www.allrecipes.com/recipe/282807/4-cheese-spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/165837/super-easy-dip-for-artichokes-or-asparagus/
# Fetching details for recipe: https://www.allrecipes.com/recipe/256417/artichoke-jalapeno-hummus-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/24660/dijon-style-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/78596/cheesy-artichoke-dip-by-jean-carper/
# Fetching details for recipe: https://www.allrecipes.com/recipe/221939/spinach-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/242445/spinach-artichoke-dip-from-reynolds-wrap/
# Fetching details for recipe: https://www.allrecipes.com/recipe/230495/tribeca-artichoke-dip/
# Fetching details for recipe: https://www.allrecipes.com/recipe/268908/vegan-spinach-dip-with-artichokes/
# Category 'artichoke-dip' has 51 recipes.
# Scraping categories:   2%|▏         | 8/378 [03:33<2:43:31, 26.52s/it]
# Scraping category: bagels
# Fetching recipes from: https://www.allrecipes.com/recipes/1537/bread/yeast-bread/bagels/
# Found 24 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/breakfast-bagel-ideas-8415826
# Fetching details for recipe: https://www.allrecipes.com/recipe/220619/real-homemade-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/7178/bread-machine-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6849/boiled-bagels/
# Fetching details for recipe: https://www.allrecipes.com/everything-bagel-grilled-cheese-recipe-8753365
# Fetching details for recipe: https://www.allrecipes.com/article/bialys-vs-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/223557/pumpernickel-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/140020/moist-passover-bagel/
# Fetching details for recipe: https://www.allrecipes.com/recipe/231089/multigrain-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/282887/air-fryer-everything-bagel-bites/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8398174/two-ingredient-air-fryer-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6928/bagels-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/231090/whole-wheat-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/244974/pumpkin-spice-bagel/
# Fetching details for recipe: https://www.allrecipes.com/article/we-tried-two-ingredient-dough-three-ways/
# Fetching details for recipe: https://www.allrecipes.com/recipe/285341/cream-cheese-filled-bagel-balls/
# Fetching details for recipe: https://www.allrecipes.com/recipe/232539/grandma-sherrills-bagels/
# Fetching details for recipe: https://www.allrecipes.com/article/two-ingredient-bagel-review/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8396921/2-ingredient-dough-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8400714/two-ingredient-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/284536/nova-lox-everything-breakfast-bagel/
# Fetching details for recipe: https://www.allrecipes.com/recipe/276902/toris-air-fryer-pumpkin-bagels/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8416567/2-ingredient-dough-air-fryer-blueberry-bagels/
# Fetching details for recipe: https://www.allrecipes.com/article/amazing-mufgel-looks-like-muffin-tastes-like-fully-loaded-bagel/
# Category 'bagels' has 24 recipes.
# Scraping categories:   2%|▏         | 9/378 [03:47<2:20:18, 22.81s/it]
# Scraping category: baked-beans
# Fetching recipes from: https://www.allrecipes.com/recipes/1673/side-dish/beans-and-peas/baked-beans/
# Found 64 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/southern-baked-beans-recipe-7554356
# Fetching details for recipe: https://www.allrecipes.com/drunken-baked-beans-frijoles-borrachos-recipe-7511596
# Fetching details for recipe: https://www.allrecipes.com/recipe/18255/boston-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/165249/baked-beans-from-scratch/
# Fetching details for recipe: https://www.allrecipes.com/recipe/21655/simple-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/58389/slow-cooker-homemade-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/232677/homemade-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/272258/instant-pot-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/236866/texas-style-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/18244/baked-beans-i/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16428/baked-beans-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/150637/better-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/24224/calico-bean-casserole/
# Fetching details for recipe: https://www.allrecipes.com/recipe/222258/slow-cooker-baked-beans-using-canned-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/83724/bacon-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/242080/slow-cooker-cowboy-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/22298/pats-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/222568/4-bean-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/239623/spicy-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/214816/3bc-best-baked-bean-casserole/
# Fetching details for recipe: https://www.allrecipes.com/recipe/8398508/the-best-barbecue-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/235182/chef-johns-boston-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/233050/apple-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/90438/slow-cooker-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/46763/texas-cowboy-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17043/slow-cooker-baked-beans-with-ham-hock/
# Fetching details for recipe: https://www.allrecipes.com/recipe/262324/bettys-3-bean-hot-dish-a-la-minnesota/
# Fetching details for recipe: https://www.allrecipes.com/recipe/32033/bean-hole-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219059/perfect-bbq-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/24758/down-home-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/255907/bourbon-and-dp-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/270409/quick-instant-pot-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/gallery/best-baked-beans-recipes/
# Fetching details for recipe: https://www.allrecipes.com/recipe/265374/baked-beans-with-beef/
# Fetching details for recipe: https://www.allrecipes.com/recipe/21519/simple-baked-beans-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/281055/simple-slow-cooker-pinto-beans-and-ham/
# Fetching details for recipe: https://www.allrecipes.com/recipe/238563/easy-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/237759/skillet-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/152938/gigantes-greek-lima-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/232728/old-fashioned-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/270955/my-big-fat-greek-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/47931/baked-beans-texas-ranger/
# Fetching details for recipe: https://www.allrecipes.com/recipe/222257/rancho-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/237985/the-best-slow-cooker-baked-beans-dads-recipe/
# Fetching details for recipe: https://www.allrecipes.com/recipe/280599/loaded-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/106068/sweet-barbeque-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/238300/picnic-baked-bean-casserole/
# Fetching details for recipe: https://www.allrecipes.com/recipe/233163/erikas-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/73362/cola-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/237925/vegetarian-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/73580/baked-meaty-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/109876/western-style-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/218516/kansas-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/274864/vegetarian-baked-beans-with-canned-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/31544/bar-b-q-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/gallery/baked-beans-from-scratch/
# Fetching details for recipe: https://www.allrecipes.com/recipe/265375/cowboy-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/222569/slow-cooked-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/231711/chuckwagon-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/86816/slow-cooker-bbq-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/241694/ranch-beans-with-beef/
# Fetching details for recipe: https://www.allrecipes.com/recipe/273450/home-style-vegetarian-baked-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/50259/gramma-beatons-brown-sugar-beans/
# Fetching details for recipe: https://www.allrecipes.com/recipe/24765/moms-baked-beans-ii/
# Category 'baked-beans' has 64 recipes.
# Scraping categories:   3%|▎         | 10/378 [04:22<2:42:27, 26.49s/it]
# Scraping category: banana-bread
# Fetching recipes from: https://www.allrecipes.com/recipes/343/bread/quick-bread/fruit-bread/banana-bread/
# Found 64 recipes so far.
# Fetching details for recipe: https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/230482/banana-chocolate-chip-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/241707/joys-easy-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17066/janets-rich-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/67937/extreme-banana-nut-bread-ebnb/
# Fetching details for recipe: https://www.allrecipes.com/article/banana-bread-mistakes/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6984/banana-sour-cream-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16952/the-best-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/article/how-to-ripen-bananas-faster/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6990/sarahs-banana-bread-muffins/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16706/banana-pumpkin-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/229021/blueberry-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/23426/almost-no-fat-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/214581/brown-sugar-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16666/banana-bran-muffins/
# Fetching details for recipe: https://www.allrecipes.com/recipe/20739/banana-loaf/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6757/simple-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/256401/cream-cheese-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/16999/grandmas-homemade-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/164205/spiced-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/141933/banana-zucchini-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/219967/chef-johns-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/7155/whole-wheat-banana-nut-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/7154/creamy-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17050/hawaiian-banana-nut-bread/
# Fetching details for recipe: https://www.allrecipes.com/gallery/best-banana-bread-recipes/
# Fetching details for recipe: https://www.allrecipes.com/recipe/242314/browned-butter-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17013/banana-peanut-butter-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/36772/maple-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17252/chocolate-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6713/easy-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/23810/grandmas-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6993/cathys-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/22722/brown-sugar-banana-nut-bread-i/
# Fetching details for recipe: https://www.allrecipes.com/recipe/240750/moms-carrot-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6765/4h-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/7024/banana-nut-bread-baked-in-a-jar/
# Fetching details for recipe: https://www.allrecipes.com/recipe/229003/banana-peach-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/222082/healthier-banana-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/285040/banana-bread-mug-cake-in-a-minute/
# Fetching details for recipe: https://www.allrecipes.com/recipe/237470/ginger-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/229353/sour-cream-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17754/janines-best-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/274529/high-protein-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/article/healthy-snacks-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/231961/double-banana-nut-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/18015/lighter-banana-muffins/
# Fetching details for recipe: https://www.allrecipes.com/recipe/239246/banana-walnut-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6894/banana-coconut-loaf/
# Fetching details for recipe: https://www.allrecipes.com/recipe/217065/gluten-free-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/279573/banana-pineapple-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/272400/einkorn-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/228442/raspberry-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/231183/quick-banana-nut-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/17281/molasses-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6921/quick-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/104999/we-be-jammin-jamaican-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/20153/chocolate-chip-banana-bread-ii/
# Fetching details for recipe: https://www.allrecipes.com/recipe/282274/best-ever-classic-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6687/banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/218978/banana-apple-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/6754/lower-fat-banana-bread-i/
# Fetching details for recipe: https://www.allrecipes.com/recipe/272797/the-best-vegan-banana-bread/
# Fetching details for recipe: https://www.allrecipes.com/recipe/24575/oatmeal-banana-nut-bread/
# Category 'banana-bread' has 64 recipes.
# Scraping categories:   3%|▎         | 11/378 [04:59<2:46:18, 27.19s/it]
# Reached the maximum number of recipes.
# Category: air-fryer
# Total Recipes: 64
# Sample Recipes:
# - Air Fryer Lemon Garlic Parmesan Chicken: https://www.allrecipes.com/air-fryer-lemon-garlic-parmesan-chicken-recipe-8726749
# - Our 15 Best Air Fryer Thanksgiving Recipes: https://www.allrecipes.com/best-air-fryer-thanksgiving-recipes-8729089
# - Air Fryer S’Mores: https://www.allrecipes.com/air-fryer-s-mores-recipe-8736955
#
# Category: allrecipes-allstars
# Total Recipes: 64
# Sample Recipes:
# - Halibut en Papillote: https://www.allrecipes.com/halibut-en-papillote-recipe-8775088
# - Thai Peanut Butter Ramen: https://www.allrecipes.com/thai-peanut-butter-ramen-recipe-8775397
# - Italian Ricotta Cookie Bars: https://www.allrecipes.com/italian-ricotta-cookie-bars-recipe-8775003
#
# Category: angel-food-cake
# Total Recipes: 15
# Sample Recipes:
# - Mock Angel Food Cake: https://www.allrecipes.com/recipe/7868/mock-angel-food-cake/
# - Heavenly Raspberry Dessert: https://www.allrecipes.com/recipe/244321/heavenly-raspberry-dessert/
# - Cherry Angel Food Cake: https://www.allrecipes.com/recipe/25981/cherry-angel-food-cake/
#
# Category: antipasto
# Total Recipes: 34
# Sample Recipes:
# - Prosciutto e Melone (Italian Ham and Melon): https://www.allrecipes.com/recipe/106695/prosciutto-e-melone-italian-ham-and-melon/
# - Cherry Pepper Poppers: https://www.allrecipes.com/recipe/53144/cherry-pepper-poppers/
# - Antipasti Garlic Bread: https://www.allrecipes.com/antipasti-garlic-bread-recipe-8716000
#
# Category: appetizers-and-snacks
# Total Recipes: 64
# Sample Recipes:
# - Chinese Tea Eggs: https://www.allrecipes.com/recipe/51326/chinese-tea-leaf-eggs/
# - Cheese Puff Sliders: https://www.allrecipes.com/cheese-puff-sliders-recipe-8768983
# - Miso Aioli: https://www.allrecipes.com/miso-aioli-recipe-8768230
#
# Category: apple-pie
# Total Recipes: 64
# Sample Recipes:
# - Caramel Apple Pie Cookies: https://www.allrecipes.com/caramel-apple-pie-cookies-recipe-7642173
# - Mom's Apple Cranberry Pie: https://www.allrecipes.com/recipe/230243/moms-cranberry-apple-pie/
# - Apple Pie by Grandma Ople: https://www.allrecipes.com/recipe/12682/apple-pie-by-grandma-ople/
#
# Category: applesauce
# Total Recipes: 31
# Sample Recipes:
# - Applesauce for the Freezer: https://www.allrecipes.com/recipe/234078/applesauce-for-the-freezer/
# - Applesauce Muffins: https://www.allrecipes.com/applesauce-muffins-recipe-8702299
# - Cranberry Sauce Extraordinaire: https://www.allrecipes.com/recipe/13643/cranberry-sauce-extraordinaire/
#
# Category: artichoke-dip
# Total Recipes: 51
# Sample Recipes:
# - Artichoke & Spinach Dip, Restaurant Style: https://www.allrecipes.com/recipe/33474/artichoke-spinach-dip-restaurant-style/
# - Instant Pot Spinach and Artichoke Dip: https://www.allrecipes.com/recipe/268013/instant-pot-spinach-and-artichoke-dip/
# - Amazing No Cook Spinach Artichoke Dip: https://www.allrecipes.com/recipe/223012/amazing-no-cook-spinach-artichoke-dip/
#
# Category: bagels
# Total Recipes: 24
# Sample Recipes:
# - 25 Breakfast Bagel Ideas That Go Way Beyond Plain Cream Cheese: https://www.allrecipes.com/breakfast-bagel-ideas-8415826
# - Real Homemade Bagels: https://www.allrecipes.com/recipe/220619/real-homemade-bagels/
# - Bread Machine Bagels: https://www.allrecipes.com/recipe/7178/bread-machine-bagels/
#
# Category: baked-beans
# Total Recipes: 64
# Sample Recipes:
# - Southern Baked Beans: https://www.allrecipes.com/southern-baked-beans-recipe-7554356
# - Frijoles Borrachos (Drunken Baked Beans): https://www.allrecipes.com/drunken-baked-beans-frijoles-borrachos-recipe-7511596
# - Boston Baked Beans: https://www.allrecipes.com/recipe/18255/boston-baked-beans/
#
# Category: banana-bread
# Total Recipes: 64
# Sample Recipes:
# - Banana Banana Bread: https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# - Banana Chocolate Chip Bread: https://www.allrecipes.com/recipe/230482/banana-chocolate-chip-bread/
# - Joy's Easy Banana Bread: https://www.allrecipes.com/recipe/241707/joys-easy-banana-bread/
#
# Scraping completado. Datos guardados en 'all_recipes.json'.

# %% [markdown]
# ## Paso 2: Conversion del archivo json a csv con dataframe
#
#
# Este código convierte un archivo JSON con información de recetas (`all_recipes.json`) en un archivo CSV (`all_recipes.csv`) utilizando `pandas`. Cada receta se transforma en una fila del DataFrame con las siguientes columnas:
# - `category`: Categoría de la receta.
# - `title`: Título de la receta.
# - `description`: Descripción breve de la receta.
# - `ingredients`: Lista de ingredientes, convertida en una cadena separada por punto y coma.
# - `steps`: Pasos de preparación, convertidos en una cadena separada por punto y coma.
# - `url`: Enlace a la receta original.
#
# El archivo CSV resultante se guarda con todas las recetas organizadas, permitiendo un análisis o procesamiento posterior. El script también muestra en la consola cuántas recetas se guardaron.

# %%
import pandas as pd
import json

# Cargar el archivo JSON
with open("all_recipes.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Transformar los datos en un DataFrame
recipes_list = []
for category, details in data.items():
    for recipe in details["recipes"]:
        recipes_list.append({
            "category": category,
            "title": recipe["title"],
            "description": recipe["description"],
            "ingredients": "; ".join(recipe["ingredients"]),  # Convertir lista en cadena separada por punto y coma
            "steps": "; ".join(recipe["steps"]),  # Convertir lista en cadena separada por punto y coma
            "url": recipe["url"]
        })

# Crear el DataFrame
df = pd.DataFrame(recipes_list)

# Guardar el DataFrame en un archivo CSV
output_file = "all_recipes.csv"
df.to_csv(output_file, index=False, encoding="utf-8")

print(f"Archivo CSV guardado como '{output_file}' con {len(df)} recetas.")
# Out:
# Archivo CSV guardado como 'all_recipes.csv' con 539 recetas.

# %% [markdown]
# Aqui se mostraran de resultado las primeras 5 filas del dataframe del archivo all_recipes.csv

# %%
import pandas as pd

# Cargar el archivo CSV
csv_file = "all_recipes.csv"
df = pd.read_csv(csv_file)

# Mostrar las primeras 5 filas del DataFrame
print(df.head())
# Out:
#     category                                       title  \
# 0  air-fryer     Air Fryer Lemon Garlic Parmesan Chicken
# 1  air-fryer  Our 15 Best Air Fryer Thanksgiving Recipes
# 2  air-fryer                           Air Fryer S’Mores
# 3  air-fryer                        Air Fryer Baked Yams
# 4  air-fryer        Lemon Garlic Butter Chicken Spiedini
#
#                                          description  \
# 0  These simple lemon garlic Parmesan chicken thi...
# 1       Thanksgiving dinner doesn't need to be hard.
# 2  This recipe for air fryer s'mores is perfect f...
# 3  These air fryer baked yams free up the oven, w...
# 4  These lemon garlic butter chicken spiedini are...
#
#                                          ingredients  \
# 0  1 1/2 pounds skinless boneless chicken thighs;...
# 1                                                NaN
# 2  1 sleeve graham crackers; 5 (1.5 ounce) chocol...
# 3                      1 yam; 1/2 teaspoon olive oil
# 4  1/2 cup extra-virgin olive oil; 1/4 cup white ...
#
#                                                steps  \
# 0  Gather all ingredients.; Dotdash Meredith Food...
# 1                                                NaN
# 2  Preheat an air fryer to 380 degrees F (193 deg...
# 3  Preheat an air fryer to 400 degrees F (200 deg...
# 4  Whisk together olive oil, wine, 2 tablespoons ...
#
#                                                  url
# 0  https://www.allrecipes.com/air-fryer-lemon-gar...
# 1  https://www.allrecipes.com/best-air-fryer-than...
# 2  https://www.allrecipes.com/air-fryer-s-mores-r...
# 3  https://www.allrecipes.com/air-fryer-baked-yam...
# 4  https://www.allrecipes.com/lemon-garlic-butter...

# %% [markdown]
# ## Paso 3: Preprocesamiento y normalización
#
#
# Este código realiza el **preprocesamiento y normalización** de los textos en un archivo CSV de recetas (`all_recipes.csv`). El proceso incluye:
# 1. **Preprocesamiento**:
#    - Convertir todo el texto a minúsculas.
#    - Eliminar caracteres especiales, puntuación y espacios múltiples.
# 2. **Normalización**:
#    - **Lematización**: Reduce las palabras a su forma base gramatical (e.g., "running" → "run").
#    - **Eliminación de stopwords**: Remueve palabras comunes como "and", "the", etc., que no aportan significado.
#
# El preprocesamiento se aplica a las columnas `title`, `description`, `ingredients` y `steps`. El resultado se guarda en un nuevo archivo CSV llamado `all_recipes_preprocessed_normalized.csv`, listo para su uso en análisis posteriores o modelos de aprendizaje automático.
#
# El script también utiliza la biblioteca NLTK para realizar la lematización y gestionar las stopwords.

# %%
import pandas as pd
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import nltk

# Descargar recursos necesarios de NLTK
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')

# Cargar el archivo CSV
csv_file = "all_recipes.csv"
df = pd.read_csv(csv_file)

# Inicializar lematizador y stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Función para preprocesar y normalizar texto
def preprocess_and_normalize(text):
    if pd.isna(text):
        return ""
    # Convertir a minúsculas
    text = text.lower()
    # Eliminar caracteres especiales y puntuación
    text = re.sub(r"[^a-z0-9áéíóúñü ]", "", text)
    # Eliminar espacios múltiples
    text = re.sub(r"\s+", " ", text).strip()
    # Tokenizar y lematizar
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    return " ".join(tokens)

# Aplicar preprocesamiento y normalización a las columnas relevantes
df["title"] = df["title"].apply(preprocess_and_normalize)
df["description"] = df["description"].apply(preprocess_and_normalize)
df["ingredients"] = df["ingredients"].apply(preprocess_and_normalize)
df["steps"] = df["steps"].apply(preprocess_and_normalize)

# Guardar el DataFrame preprocesado y normalizado en un nuevo archivo CSV
output_file = "all_recipes_preprocessed_normalized.csv"
df.to_csv(output_file, index=False, encoding="utf-8")

print(f"Preprocesamiento y normalización completados. Archivo guardado como '{output_file}'.")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Preprocesamiento y normalización completados. Archivo guardado como 'all_recipes_preprocessed_normalized.csv'.

# %% [markdown]
# Se cargara el archivo creado con el código anterior y se mostraran los 5 datos del archivo

# %%
import pandas as pd

# Cargar el archivo CSV preprocesado y normalizado
csv_file = "all_recipes_preprocessed_normalized.csv"
df = pd.read_csv(csv_file)

# Mostrar las primeras 5 filas del DataFrame
print("Primeros 5 datos del archivo preprocesado y normalizado:")
print(df.head())
# Out:
# Primeros 5 datos del archivo preprocesado y normalizado:
#     category                                    title  \
# 0  air-fryer  air fryer lemon garlic parmesan chicken
# 1  air-fryer    15 best air fryer thanksgiving recipe
# 2  air-fryer                         air fryer smores
# 3  air-fryer                      air fryer baked yam
# 4  air-fryer     lemon garlic butter chicken spiedini
#
#                                          description  \
# 0  simple lemon garlic parmesan chicken thigh coo...
# 1               thanksgiving dinner doesnt need hard
# 2  recipe air fryer smores perfect time craving b...
# 3  air fryer baked yam free oven especially helpf...
# 4  lemon garlic butter chicken spiedini airfried ...
#
#                                          ingredients  \
# 0  1 12 pound skinless boneless chicken thigh 3 c...
# 1                                                NaN
# 2  1 sleeve graham cracker 5 15 ounce chocolate c...
# 3                        1 yam 12 teaspoon olive oil
# 4  12 cup extravirgin olive oil 14 cup white wine...
#
#                                                steps  \
# 0  gather ingredient dotdash meredith food studio...
# 1                                                NaN
# 2  preheat air fryer 380 degree f 193 degree c la...
# 3  preheat air fryer 400 degree f 200 degree c sc...
# 4  whisk together olive oil wine 2 tablespoon lem...
#
#                                                  url
# 0  https://www.allrecipes.com/air-fryer-lemon-gar...
# 1  https://www.allrecipes.com/best-air-fryer-than...
# 2  https://www.allrecipes.com/air-fryer-s-mores-r...
# 3  https://www.allrecipes.com/air-fryer-baked-yam...
# 4  https://www.allrecipes.com/lemon-garlic-butter...

# %% [markdown]
# ## Paso 4: Embeddings
#
# Este código utiliza el modelo de `SentenceTransformer` para generar **embeddings** (representaciones vectoriales) de las recetas contenidas en un archivo CSV preprocesado (`all_recipes_preprocessed_normalized.csv`). El flujo es el siguiente:
#
# 1. **Preparación del texto**:
#    - Combina las columnas `title`, `description`, `ingredients` y `steps` en un único campo llamado `combined_text`.
#
# 2. **Generación de embeddings**:
#    - Usa el modelo `all-mpnet-base-v2` para convertir cada texto combinado en un vector de alta dimensión que captura su significado semántico.
#
# 3. **Guardado de resultados**:
#    - Los embeddings se guardan en un archivo binario llamado `recipe_embeddings.npy`.
#    - El DataFrame actualizado, con los textos combinados y los índices de embeddings, se guarda en `all_recipes_with_embeddings.csv`.
#
# 4. **Validación**:
#    - Muestra las primeras 5 recetas con sus títulos e índices de embeddings para verificar que los datos se procesaron correctamente.
#
# Este código es útil para preparar las recetas para búsquedas semánticas o para entrenar modelos de aprendizaje automático.

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np

# Cargar el archivo CSV preprocesado y normalizado
csv_file = "all_recipes_preprocessed_normalized.csv"
df = pd.read_csv(csv_file)

# Inicializar el modelo de embeddings
model = SentenceTransformer('all-mpnet-base-v2')

# Combinar las columnas relevantes en un solo texto para cada receta
def combine_text(row):
    return f"{row['title']} {row['description']} {row['ingredients']} {row['steps']}"

df['combined_text'] = df.apply(combine_text, axis=1)

# Generar embeddings para cada receta
print("Generando embeddings...")
embeddings = model.encode(df['combined_text'].tolist(), show_progress_bar=True)

# Guardar los embeddings como un archivo separado
np.save("recipe_embeddings.npy", embeddings)

# Agregar una columna con los índices de los embeddings en el DataFrame
df['embedding_index'] = range(len(embeddings))

# Guardar el DataFrame con los índices de embeddings
output_file = "all_recipes_with_embeddings.csv"
df.to_csv(output_file, index=False, encoding="utf-8")

print(f"Embeddings generados y guardados. Archivo guardado como '{output_file}'.")

# Mostrar una muestra de 5 datos para validar
print("Muestra de 5 datos del DataFrame con embeddings:")
print(df[['title', 'embedding_index']].head(5))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Generando embeddings...
# Batches:   0%|          | 0/17 [00:00<?, ?it/s]
# Embeddings generados y guardados. Archivo guardado como 'all_recipes_with_embeddings.csv'.
# Muestra de 5 datos del DataFrame con embeddings:
#                                      title  embedding_index
# 0  air fryer lemon garlic parmesan chicken                0
# 1    15 best air fryer thanksgiving recipe                1
# 2                         air fryer smores                2
# 3                      air fryer baked yam                3
# 4     lemon garlic butter chicken spiedini                4

# %% [markdown]
# ## Instalación de dependencias
#
# Este bloque de código instala **FAISS**.
#
# 1. **Instalación del paquete FAISS a través de `apt`**:
#    - `!apt-get install -y libfaiss-dev`: Instala las bibliotecas base de FAISS en el sistema operativo.
#
# 2. **Instalación del módulo de Python**:
#    - `!pip install faiss-cpu`: Instala la versión compatible con CPU de la biblioteca FAISS para Python.
#
# Estas instalaciones son necesarias para usar FAISS en Python, lo cual es útil para realizar búsquedas rápidas y eficientes en grandes bases de datos vectoriales.

# %%
# !apt-get install -y libfaiss-dev
# !pip install faiss-cpu
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libfaiss-dev
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 949 kB of archives.
# After this operation, 6,224 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfaiss-dev amd64 1.7.2-5 [949 kB]
# Fetched 949 kB in 1s (1,287 kB/s)
# Selecting previously unselected package libfaiss-dev:amd64.
# (Reading database ... 124574 files and directories currently installed.)
# Preparing to unpack .../libfaiss-dev_1.7.2-5_amd64.deb ...
# Unpacking libfaiss-dev:amd64 (1.7.2-5) ...
# Setting up libfaiss-dev:amd64 (1.7.2-5) ...
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 40.1 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0.post1

# %%
import faiss
print("FAISS importado correctamente.")
# Out:
# FAISS importado correctamente.

# %% [markdown]
# ## Paso 5: Faiss
#
# Este código utiliza la biblioteca **FAISS** para crear un índice de similitud basado en los embeddings generados previamente, permitiendo realizar búsquedas eficientes en el espacio vectorial.
#
# 1. **Cargar embeddings**:
#    - Se cargan los embeddings desde el archivo `recipe_embeddings.npy`.
#
# 2. **Crear el índice FAISS**:
#    - Se inicializa un índice plano (`IndexFlatL2`) basado en la distancia Euclidiana (L2) para calcular similitudes entre vectores.
#
# 3. **Agregar embeddings al índice**:
#    - Los vectores de embeddings se agregan al índice FAISS para su futura búsqueda.
#
# 4. **Verificar el índice**:
#    - Muestra cuántos vectores (embeddings) han sido indexados.
#
# 5. **Guardar el índice**:
#    - El índice FAISS se guarda en un archivo llamado `faiss_recipe_index.index` para reutilizarlo posteriormente.
#
# Este código es una etapa clave para sistemas de búsqueda semántica, ya que organiza los embeddings en una estructura eficiente para realizar consultas rápidas.

# %%
import faiss
import numpy as np

# Cargar los embeddings generados previamente
embeddings_file = "recipe_embeddings.npy"
embeddings = np.load(embeddings_file)

# Crear un índice FAISS (Flat Index para búsquedas de similitud exacta)
embedding_dimension = embeddings.shape[1]  # Dimensión de los vectores
index = faiss.IndexFlatL2(embedding_dimension)  # Índice con distancia L2 (Euclidiana)

# Agregar los embeddings al índice
print("Agregando embeddings al índice FAISS...")
index.add(embeddings)

# Verificar cuántos embeddings se han indexado
print(f"Número de embeddings en el índice: {index.ntotal}")

# Guardar el índice FAISS
faiss.write_index(index, "faiss_recipe_index.index")
print("Índice FAISS guardado como 'faiss_recipe_index.index'.")
# Out:
# Agregando embeddings al índice FAISS...
# Número de embeddings en el índice: 539
# Índice FAISS guardado como 'faiss_recipe_index.index'.

# %% [markdown]
# ## Resultados con busquedas
#
# Este código realiza **búsquedas** en un índice FAISS previamente creado, utilizando embeddings generados con Sentence Transformers. Permite encontrar recetas similares a una consulta de texto.
#
# 1. **Cargar los datos**:
#    - Se carga el índice FAISS (`faiss_recipe_index.index`), los embeddings originales (`recipe_embeddings.npy`), y el DataFrame con información de recetas (`all_recipes_with_embeddings.csv`).
#
# 2. **Modelo de embeddings**:
#    - Utiliza `SentenceTransformer` (`all-mpnet-base-v2`) para convertir la consulta en un embedding vectorial.
#
# 3. **Consulta en FAISS**:
#    - La función `query_faiss`:
#      - Genera un embedding para la consulta de texto.
#      - Busca los `k` vecinos más cercanos en el índice FAISS.
#      - Recupera las recetas más relevantes, incluyendo su título, descripción, y la distancia calculada.
#
# 4. **Resultados**:
#    - Muestra los `k` resultados más relevantes para la consulta `"apple pie with cinnamon"`, ordenados por similitud (distancia más baja).
#
# Este código es ideal para implementar sistemas de búsqueda semántica en bases de datos grandes, utilizando embeddings para capturar el significado del texto y FAISS para realizar consultas rápidas.

# %% [markdown]
# ### Consulta #1

# %%
import faiss
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer

# Cargar el índice FAISS
index_file = "faiss_recipe_index.index"
index = faiss.read_index(index_file)

# Cargar los embeddings originales y el DataFrame de recetas
embeddings_file = "recipe_embeddings.npy"
embeddings = np.load(embeddings_file)

data_file = "all_recipes_with_embeddings.csv"
df = pd.read_csv(data_file)

# Inicializar el modelo de embeddings para procesar consultas
model = SentenceTransformer('all-mpnet-base-v2')

# Función para realizar una consulta en el índice FAISS
def query_faiss(query, k=5):
    # Generar el embedding de la consulta
    query_embedding = model.encode([query])

    # Buscar los k vecinos más cercanos
    distances, indices = index.search(query_embedding, k)

    # Mostrar resultados
    results = []
    for i, idx in enumerate(indices[0]):
        result = {
            "rank": i + 1,
            "title": df.loc[idx, "title"],
            "description": df.loc[idx, "description"],
            "distance": distances[0][i]
        }
        results.append(result)
    return results

# Prueba de consulta
query_text = "apple pie with cinnamon"
k = 5
results = query_faiss(query_text, k)

print(f"Resultados para la consulta: '{query_text}'")
for result in results:
    print(f"Rank {result['rank']}: {result['title']} (Distancia: {result['distance']:.4f})")
# Out:
# Resultados para la consulta: 'apple pie with cinnamon'
# Rank 1: sunday apple pie (Distancia: 0.4953)
# Rank 2: nosugar apple pie (Distancia: 0.5543)
# Rank 3: easy apple pie (Distancia: 0.5604)
# Rank 4: spiced apple topping pancake (Distancia: 0.5752)
# Rank 5: apple crumble pie (Distancia: 0.5934)

# %% [markdown]
# ### Consulta #2

# %%
import faiss
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer

# Cargar el índice FAISS
index_file = "faiss_recipe_index.index"
index = faiss.read_index(index_file)

# Cargar los embeddings originales y el DataFrame de recetas
embeddings_file = "recipe_embeddings.npy"
embeddings = np.load(embeddings_file)

data_file = "all_recipes_with_embeddings.csv"
df = pd.read_csv(data_file)

# Inicializar el modelo de embeddings para procesar consultas
model = SentenceTransformer('all-mpnet-base-v2')

# Función para realizar una consulta en el índice FAISS
def query_faiss(query, k=5):
    # Generar el embedding de la consulta
    query_embedding = model.encode([query])

    # Buscar los k vecinos más cercanos
    distances, indices = index.search(query_embedding, k)

    # Mostrar resultados
    results = []
    for i, idx in enumerate(indices[0]):
        result = {
            "rank": i + 1,
            "title": df.loc[idx, "title"],
            "description": df.loc[idx, "description"],
            "distance": distances[0][i]
        }
        results.append(result)
    return results

# Prueba de consulta
query_text = "chicken"
k = 5
results = query_faiss(query_text, k)

print(f"Resultados para la consulta: '{query_text}'")
for result in results:
    print(f"Rank {result['rank']}: {result['title']} (Distancia: {result['distance']:.4f})")
# Out:
# Resultados para la consulta: 'chicken'
# Rank 1: bang bang chicken nugget (Distancia: 1.1280)
# Rank 2: turmeric black pepper chicken broccoli (Distancia: 1.1507)
# Rank 3: air fryer chicken bite (Distancia: 1.1663)
# Rank 4: lemon garlic butter chicken spiedini (Distancia: 1.1772)
# Rank 5: lemon garlic butter chicken spiedini (Distancia: 1.1772)
